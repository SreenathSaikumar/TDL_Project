# %% [markdown]
# # Metastatic tissue identifier with Convolutional Neural Networks:
#
# Welcome folks!, in the current project we will implement a CNN by scratch to classify images of tissues as cancerous or not, for this we have to make use of the **Histopathologic Cancer Detection** competition dataset which contains over 220 thousand images for training set and 57458 unseen images to classify and submit.
#
# Having said that, let's get started!

# %% [markdown]
# Firstly, we have to import the main libraries to perform EDA as follows:

# %%
#pip install visualkeras

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
#import visualkeras
import tensorflow as tf

# %% [markdown]
# ## Exploratory Data Analysis:
#
# Now, we will print the files available in the main directory so as to know the distribution of images.

# %%
os.listdir('input/histopathologic-cancer-detection')
# Out:
# ['test', 'sample_submission.csv', 'train', 'train_labels.csv']

# %% [markdown]
# Let's print the file name of the first five images in the training dataset:

# %%
os.listdir('input/histopathologic-cancer-detection/train')[:5]
# Out:
# ['61d65976d4a3669e40462aea2666e3feca2ba958.tif',
#  'd7410382107f7368ed73e1c66328bd050899fe55.tif',
#  '27ea356220d5687e6a68355bdafa59c7010c0c0c.tif',
#  'c8189b64b09f72626f689c22c0c3ecc8dba7afc7.tif',
#  'cc335a0b4397b49498b512902b09af5f56af383c.tif']

# %% [markdown]
# In order to know the exact number of images in each folder we will print the length of the list containing the file names as can be seen below:

# %%
len(os.listdir('input/histopathologic-cancer-detection/train'))
# Out:
# 220025

# %%
len(os.listdir('input/histopathologic-cancer-detection/test'))
# Out:
# 57458

# %% [markdown]
# Perfect, the dataset author gives a csv file containing the images id's and their respective category in two columns, let's print it in the next line:

# %%
df=pd.read_csv('input/histopathologic-cancer-detection/train_labels.csv')
df.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %% [markdown]
# The next step is to plot the distribution of categories as proportions just to know if the data is balanced or not.

# %%
df.label.value_counts()
# Out:
# 0    130908
# 1     89117
# Name: label, dtype: int64

# %%
sns.set(style='whitegrid')
pie_chart=pd.DataFrame(df['label'].replace(0,'Non-cancerous tissue').replace(1,'Cancerous tissue').value_counts())
pie_chart.reset_index(inplace=True)
pie_chart.plot(kind='pie', title='Category Images',y = 'label', 
             autopct='%1.1f%%', shadow=False, labels=pie_chart['index'], legend = False, fontsize=14, figsize=(18,8))
# Out:
# <AxesSubplot:title={'center':'Category Images'}, ylabel='label'>

# %% [markdown]
# Evidently the dataset is unbalanced and for this task I prefer to undersample to the lowest number which corresponds to 89117 avoiding sidetracked predictions in our future model, as my main purpose is to make you understand better the process we will simplify the number to 89000 so as to not get confused in the splitting process later.
#
# In the following lines I will print the first image contained in training set and its corresponding category by using its id in the csv file:

# %%
from PIL import Image

# %%
im = Image.open('input/histopathologic-cancer-detection/train/'+os.listdir('input/histopathologic-cancer-detection/train')[0])
plt.imshow(im)
plt.axis('off')
print(df[df.id==os.listdir('input/histopathologic-cancer-detection/train')[0].split('.')[0]].label)
# Out:
# 177217    0
# Name: label, dtype: int64

# %% [markdown]
# Above we see the the first training image has label:1 corresponding to metastatic tissue, let's see more examples about both categories by running the following lines. If you want to see more on the next functions to print images by categories I encourage you to take a look at my next notebook in which I explain it much detailed:
#
# https://www.kaggle.com/georgesaavedra/best-intel-image-classifiers

# %%
Labels = df.label.values
Labels
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
def get_indexes(label,list_n):
  for x in range(len(Labels)):
    if Labels[x]==label:
      list_n.append(x)
  return list_n

# %%
no_cancer=[]
no_cancer=get_indexes(0,no_cancer)
cancer=[]
cancer=get_indexes(1,cancer)

# %%
def get_classlabel(class_code):
    labels = {0:'Non-cancerous', 1:'Cancerous'}
    
    return labels[class_code]

# %%
import random
from random import randint

f,ax = plt.subplots(2,4, figsize=(12,12)) 
types_img=[no_cancer, cancer]

for z in range(0,2,1):
    for j in range(0,4,1):
        rnd_number=random.choice(types_img[z])
        ax[z,j].imshow(Image.open('input/histopathologic-cancer-detection/train/'+df.iloc[rnd_number,0]+'.tif'))
        ax[z,j].set_title(get_classlabel(z))
        ax[z,j].axis('off')
        plt.tight_layout()

# %% [markdown]
# ## Data Preparation:
#
# We will get rid of the next images as they either create errors during training or doesn't represent its category:

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(17,17))

ax1.imshow(Image.open('input/histopathologic-cancer-detection/train/'+'dd6dfed324f9fcb6f93f46f32fc800f2ec196be2.tif'))
ax1.axis('off')
ax1.set_title('Error Image')

ax2.imshow(Image.open('input/histopathologic-cancer-detection/train/'+'9369c7278ec8bcc6c880d99194de09fc2bd4efbe.tif'))
ax2.axis('off')
ax2.set_title('Black Image')
# Out:
# Text(0.5, 1.0, 'Black Image')

# %%
df.shape
# Out:
# (220025, 2)

# %%
# removing this image because it caused a training error previously
df = df[df['id'] != 'dd6dfed324f9fcb6f93f46f32fc800f2ec196be2']

# removing this image because it's black
df = df[df['id'] != '9369c7278ec8bcc6c880d99194de09fc2bd4efbe']

print(df.shape)
# Out:
# (220023, 2)

# %% [markdown]
# Once we got rid of both images we have to create dataframes containing the id's of each category and gather 89000 images as we said earlier randomly:

# %%
SAMPLE_SIZE=89000

# take a random sample of class 0 with size equal to num samples in class 1
df_0 = df[df['label'] == 0].sample(SAMPLE_SIZE, random_state = 42)
# filter out class 1
df_1 = df[df['label'] == 1].sample(SAMPLE_SIZE, random_state = 42)

# %% [markdown]
# Once we created both dataframes we will concatenate them so as to have one file containing 178000 images, finally we will shuffle it because it was sorted:

# %%
from sklearn.utils import shuffle

# concat the dataframes
df_data = pd.concat([df_0, df_1], axis=0).reset_index(drop=True)
# shuffle
df_data = shuffle(df_data)

df_data['label'].value_counts()
# Out:
# 0    89000
# 1    89000
# Name: label, dtype: int64

# %%
df_data.head(10)
# Out:
#                                               id  label
# 29666   2d22e11b1bd47fab6e187f86a62402d0c545c866      0
# 32826   6ad46d8f3571bc9dded7514cb6a25dbc181e79b8      0
# 49070   75730a2f95a39d569eda0758bf701b09b147c211      0
# 112045  6e97befe619265af04b662c963163a628e4ffc89      1
# 82841   d9db2a8a91a56348fa44deb04a79d3ec507ebd2b      0
# 34973   95236b2a505b093d270ec36ff4174c9250dccac4      0
# 143094  c9d6ad0c2df8f33cd7bc15c298e90267339b7ea1      1
# 132804  9808078bceb772e4d7868b708d4eb01b86c2a52d      1
# 120530  beb4f7207a2fbf4b2eb35966b09dc3dd4cc10d94      1
# 55119   5564cdd019a081312abfe802ee5a22ccfde52390      0

# %% [markdown]
# Now that we have a balanced dataset we can split into training and validation sets at 10% as a typical ML workflow.

# %%
# train_test_split
from sklearn.model_selection import train_test_split

# stratify=y creates a balanced validation set.
y = df_data['label']

df_train, df_val = train_test_split(df_data, test_size=0.10, random_state=42, stratify=y)

print(df_train.shape)
print(df_val.shape)
# Out:
# (160200, 2)
# (17800, 2)

# %% [markdown]
# We can see the number of images in both sets make sense and kept the balance.

# %%
df_train['label'].value_counts()
# Out:
# 0    80100
# 1    80100
# Name: label, dtype: int64

# %%
df_val['label'].value_counts()
# Out:
# 0    8900
# 1    8900
# Name: label, dtype: int64

# %% [markdown]
# At this moment we could create the model and the objects containing the training and validation images according to the id's in both sets, however this process will crash our machine RAM forcing us to restart it, this is why we have to create directories and sub-directories and save the images in their respective folder, this process will consume a significative lower RAM allowing us to succesfully train our model for various epochs.
#
# As I said we will create a base directory containing training and testing sub-directories and these will contain folders for categories 'Cancerous' and 'Non-Cancerous', we will perform this step-by-step as follows:

# %%
# Create a new directory
base_dir = 'base_dir'
os.mkdir(base_dir)

#[CREATE FOLDERS INSIDE THE BASE DIRECTORY]
# train_dir
train_dir = os.path.join(base_dir, 'train_dir')
os.mkdir(train_dir)

# val_dir
val_dir = os.path.join(base_dir, 'val_dir')
os.mkdir(val_dir)

# [CREATE FOLDERS INSIDE THE TRAIN AND VALIDATION FOLDERS]
# Inside each folder we create separate folders for each class

# create new folders inside train_dir
non_cancerous_tissue = os.path.join(train_dir, 'non_cancerous_tissue')
os.mkdir(non_cancerous_tissue)
cancerous_tissue = os.path.join(train_dir, 'cancerous_tissue')
os.mkdir(cancerous_tissue)

# create new folders inside val_dir
non_cancerous_tissue = os.path.join(val_dir, 'non_cancerous_tissue')
os.mkdir(non_cancerous_tissue)
cancerous_tissue = os.path.join(val_dir, 'cancerous_tissue')
os.mkdir(cancerous_tissue)

# %% [markdown]
# We have to set the 'id' column as index in order to gather the image labels more easily, this will help us when copying the images to our just created directories:

# %%
# Set the id as the index in df_data
df_data.set_index('id', inplace=True)

# %%
df_data.head()
# Out:
#                                           label
# id
# 2d22e11b1bd47fab6e187f86a62402d0c545c866      0
# 6ad46d8f3571bc9dded7514cb6a25dbc181e79b8      0
# 75730a2f95a39d569eda0758bf701b09b147c211      0
# 6e97befe619265af04b662c963163a628e4ffc89      1
# d9db2a8a91a56348fa44deb04a79d3ec507ebd2b      0

# %% [markdown]
# Time to copy the images to their respective directories:

# %%
import shutil

# Get a list of train and val images
train_list = list(df_train['id'])
val_list = list(df_val['id'])

# Transfer the train images
for image in train_list:
    # the id in the csv file does not have the .tif extension therefore we add it here
    fname = image + '.tif'
    # get the label for a certain image
    target = df_data.loc[image,'label']
    
    # these must match the folder names
    if target == 0:
        label = 'non_cancerous_tissue'
    if target == 1:
        label = 'cancerous_tissue'
    
    # source path to image
    src = os.path.join('input/histopathologic-cancer-detection/train', fname)
    # destination path to image
    dst = os.path.join(train_dir, label, fname)
    # copy the image from the source to the destination
    shutil.copyfile(src, dst)


# Transfer the val images
for image in val_list:
    # the id in the csv file does not have the .tif extension therefore we add it here
    fname = image + '.tif'
    # get the label for a certain image
    target = df_data.loc[image,'label']
    
    # these must match the folder names
    if target == 0:
        label = 'non_cancerous_tissue'
    if target == 1:
        label = 'cancerous_tissue'
    
    # source path to image
    src = os.path.join('input/histopathologic-cancer-detection/train', fname)
    # destination path to image
    dst = os.path.join(val_dir, label, fname)
    # copy the image from the source to the destination
    shutil.copyfile(src, dst)

# %% [markdown]
# To confirm that the images were succefully copied we will print the amount of images in each folder of the directories, the numbers should correspond to the same we got when the dataset was splitted:

# %%
# check how many training images we have in each folder
print(len(os.listdir('base_dir/train_dir/non_cancerous_tissue')))
print(len(os.listdir('base_dir/train_dir/cancerous_tissue')))
# Out:
# 80100
# 80100

# %%
# check how many validation images we have in each folder
print(len(os.listdir('base_dir/val_dir/non_cancerous_tissue')))
print(len(os.listdir('base_dir/val_dir/cancerous_tissue')))
# Out:
# 8900
# 8900

# %% [markdown]
# Perfect, now our images are available in in the 'Output Data' using such memory. We could start creating our model and training it with flow_from_directory, however in order to increase the accuracy we will perform Data Augmentation by creating flipped, shifted and rotated images based on the existing ones and obviously scale them, as we are working with images the proper process is min-max scaling and this can be done in the augmentation process.

# %%
train_path = 'base_dir/train_dir'
valid_path = 'base_dir/val_dir'
test_path = 'input/test'

num_train_samples = len(df_train)
num_val_samples = len(df_val)
train_batch_size = 32
val_batch_size = 32

train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)

# %% [markdown]
# ImageDataGenerator allows us to augment our data and this function will be applied to our training and validation by gathering them with the flow_from_directory function, notice that we have to shuffle both as this is a new function and we have to create a another validation set unshuffled in which we will perform a new prediction to compute the error metrics:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMAGE_SIZE=96
datagen = ImageDataGenerator(rescale=1.0/255,
                             featurewise_center=False,
                             samplewise_center=False,
                             featurewise_std_normalization=False,
                             samplewise_std_normalization=False,
                             zca_whitening=False,
                             rotation_range=10,
                             zoom_range = 0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='binary',
                                        shuffle=True)

val_gen = datagen.flow_from_directory(valid_path,
                                      target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                      batch_size=val_batch_size,
                                      class_mode='binary',
                                      shuffle=True)

# Note: shuffle=False causes the test dataset to not be shuffled
val2_gen = datagen.flow_from_directory(valid_path,
                                       target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                       batch_size=1,
                                       class_mode='binary',
                                       shuffle=False)
# Out:
# Found 160200 images belonging to 2 classes.
# Found 17800 images belonging to 2 classes.
# Found 17800 images belonging to 2 classes.

# %% [markdown]
# Nice!, the function found all images distributed into two classes, these objects will be used as arguments when training the model.

# %% [markdown]
# ## Modeling:
#
# We will start by importing all libraries and functions needed to create the model as follows:

# %%
from sklearn.metrics import confusion_matrix
import itertools

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Reshape, LSTM
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adadelta

# %% [markdown]
# Before we start creating our model we will define three callbacks that will help us to improve the training, stop it once it reaches a threshold and save the best model according to its accuracy:

# %%
#Will stop the training once it reaches 99% validation accuracy:
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy')>0.99):
      print("\nReached 99% accuracy so cancelling training!")
      self.model.stop_training = True
        
callbacks = myCallback()

#Will reduce the learning rate is validation accuracy didn't improve in one epoch:
from tensorflow.keras.callbacks import ReduceLROnPlateau
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                 patience=1, 
                                 verbose=1, 
                                 factor=0.5, 
                                 min_lr=0.000001)

#Will save the very best model according to validation accuracy:
from tensorflow.keras.callbacks import ModelCheckpoint
model_dir = 'CNN_model_histo.h5'
checkpoint = ModelCheckpoint(model_dir, monitor='val_accuracy', verbose=1,
                             save_best_only=True, mode='max')

# %% [markdown]
# The architecture I decided to use was made in one of my previous projects in which the performance was considerably high, it considers 4 sets of layers including 2D-Convolutional, 2D-Max Pooling and Batch Normalization, at the end we add a couple of Dropout and Dense layers.
#
# I kindly encourage you to take a look at the following notebook in which I explain such architecture much better and aims a similar task:
#
# https://www.kaggle.com/georgesaavedra/tumor-classification-cnn

# %%
optimizer = Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

model=Sequential()
model.add(Conv2D(32,(3,3),strides=1,padding='Same',activation='relu',input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)))
model.add(MaxPool2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3), strides=1,padding= 'Same', activation='relu'))
model.add(MaxPool2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3), strides=1,padding= 'Same', activation='relu'))
model.add(MaxPool2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3), strides=1,padding= 'Same', activation='relu'))
model.add(MaxPool2D(2,2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation = "relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = optimizer , loss = "binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 96, 96, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dropout_2 (Dropout)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 512)               4719104
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 5,109,953
# Trainable params: 5,108,993
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# The following function displays our model architecture by layers, not showing the layers detail though, however we can follow and associate each color to a type of layer, such as: Yelow: Conv2D, Red: MaxPooling, Green: BatchNormalization, Blue:Flatten, Black: Dropout, Yelow: Dense.

# %%
#visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=1427x512 at 0x7F6B82947D90>

# %% [markdown]
# Time now to train our model using the objects pointing to our created directories, we will train for 20 epochs so as to find the best possible model.
#
# *Important: Notice that for the deep of our network it will take a considerably long time to train, where each epoch took me around 8 minutes and 20 seconds, so be patient if you want to train it again.*

# %%
history = model.fit(train_gen, validation_data=val_gen,
                              epochs=20, verbose=1,
                              callbacks=[callbacks, lr_reduction, checkpoint])
# Out:
# Epoch 1/20
# 2022-04-20 19:18:46.295946: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8303
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3958 - accuracy: 0.8346
# Epoch 1: val_accuracy improved from -inf to 0.70972, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 406s 80ms/step - loss: 0.3958 - accuracy: 0.8346 - val_loss: 0.6514 - val_accuracy: 0.7097 - lr: 0.0010
# Epoch 2/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.8840
# Epoch 2: val_accuracy improved from 0.70972 to 0.80169, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 266s 53ms/step - loss: 0.2892 - accuracy: 0.8840 - val_loss: 0.7342 - val_accuracy: 0.8017 - lr: 0.0010
# Epoch 3/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2508 - accuracy: 0.9026
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 3: val_accuracy did not improve from 0.80169
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2508 - accuracy: 0.9026 - val_loss: 0.7093 - val_accuracy: 0.7315 - lr: 0.0010
# Epoch 4/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9211
# Epoch 4: val_accuracy improved from 0.80169 to 0.90545, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2064 - accuracy: 0.9211 - val_loss: 0.2298 - val_accuracy: 0.9054 - lr: 5.0000e-04
# Epoch 5/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9265
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 5: val_accuracy did not improve from 0.90545
# 5007/5007 [==============================] - 245s 49ms/step - loss: 0.1928 - accuracy: 0.9265 - val_loss: 0.2971 - val_accuracy: 0.8938 - lr: 5.0000e-04
# Epoch 6/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9361
# Epoch 6: val_accuracy improved from 0.90545 to 0.93371, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 245s 49ms/step - loss: 0.1707 - accuracy: 0.9361 - val_loss: 0.1683 - val_accuracy: 0.9337 - lr: 2.5000e-04
# Epoch 7/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9384
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 7: val_accuracy did not improve from 0.93371
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1665 - accuracy: 0.9384 - val_loss: 0.1788 - val_accuracy: 0.9308 - lr: 2.5000e-04
# Epoch 8/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9423
# Epoch 8: val_accuracy improved from 0.93371 to 0.93910, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1557 - accuracy: 0.9423 - val_loss: 0.1610 - val_accuracy: 0.9391 - lr: 1.2500e-04
# Epoch 9/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9429
# Epoch 9: val_accuracy improved from 0.93910 to 0.94506, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 246s 49ms/step - loss: 0.1528 - accuracy: 0.9429 - val_loss: 0.1462 - val_accuracy: 0.9451 - lr: 1.2500e-04
# Epoch 10/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9447
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 10: val_accuracy did not improve from 0.94506
# 5007/5007 [==============================] - 243s 48ms/step - loss: 0.1501 - accuracy: 0.9447 - val_loss: 0.1624 - val_accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 11/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9466
# Epoch 11: val_accuracy improved from 0.94506 to 0.94573, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1445 - accuracy: 0.9466 - val_loss: 0.1421 - val_accuracy: 0.9457 - lr: 6.2500e-05
# Epoch 12/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9471
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 12: val_accuracy did not improve from 0.94573
# 5007/5007 [==============================] - 243s 48ms/step - loss: 0.1424 - accuracy: 0.9471 - val_loss: 0.1483 - val_accuracy: 0.9438 - lr: 6.2500e-05
# Epoch 13/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.1397 - accuracy: 0.9479
# Epoch 13: val_accuracy improved from 0.94573 to 0.95388, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 244s 49ms/step - loss: 0.1397 - accuracy: 0.9479 - val_loss: 0.1206 - val_accuracy: 0.9539 - lr: 3.1250e-05
# Epoch 14/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9484
# Epoch 14: val_accuracy improved from 0.95388 to 0.95449, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 244s 49ms/step - loss: 0.1378 - accuracy: 0.9484 - val_loss: 0.1208 - val_accuracy: 0.9545 - lr: 3.1250e-05
# Epoch 15/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9490
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 15: val_accuracy did not improve from 0.95449
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1380 - accuracy: 0.9490 - val_loss: 0.1231 - val_accuracy: 0.9536 - lr: 3.1250e-05
# Epoch 16/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9492
# Epoch 16: val_accuracy improved from 0.95449 to 0.95758, saving model to CNN_model_histo.h5
# 5007/5007 [==============================] - 244s 49ms/step - loss: 0.1365 - accuracy: 0.9492 - val_loss: 0.1172 - val_accuracy: 0.9576 - lr: 1.5625e-05
# Epoch 17/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.1365 - accuracy: 0.9491
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 17: val_accuracy did not improve from 0.95758
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1364 - accuracy: 0.9492 - val_loss: 0.1170 - val_accuracy: 0.9565 - lr: 1.5625e-05
# Epoch 18/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9500
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 18: val_accuracy did not improve from 0.95758
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1346 - accuracy: 0.9500 - val_loss: 0.1160 - val_accuracy: 0.9576 - lr: 7.8125e-06
# Epoch 19/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9497
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 19: val_accuracy did not improve from 0.95758
# 5007/5007 [==============================] - 243s 49ms/step - loss: 0.1345 - accuracy: 0.9497 - val_loss: 0.1141 - val_accuracy: 0.9573 - lr: 3.9063e-06
# Epoch 20/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9501
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 20: val_accuracy did not improve from 0.95758
# 5007/5007 [==============================] - 245s 49ms/step - loss: 0.1347 - accuracy: 0.9501 - val_loss: 0.1163 - val_accuracy: 0.9571 - lr: 1.9531e-06

# %% [markdown]
# The best model reached 95.37% validation accuracy and was saved in the CNN_model_histo.h5 file that we will load, but before we have to plot the performance curves in relation to the epochs:

# %%
pd.DataFrame(history.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   0.395796  0.834601  0.651430      0.709719  0.001000
# 1   0.289166  0.883989  0.734206      0.801685  0.001000
# 2   0.250790  0.902615  0.709318      0.731517  0.001000
# 3   0.206444  0.921067  0.229809      0.905449  0.000500
# 4   0.192805  0.926517  0.297076      0.893764  0.000500
# 5   0.170713  0.936086  0.168331      0.933708  0.000250
# 6   0.166515  0.938352  0.178754      0.930786  0.000250
# 7   0.155680  0.942335  0.161000      0.939101  0.000125
# 8   0.152848  0.942871  0.146189      0.945056  0.000125
# 9   0.150081  0.944744  0.162428      0.937472  0.000125
# 10  0.144526  0.946567  0.142105      0.945730  0.000063
# 11  0.142393  0.947066  0.148305      0.943764  0.000063
# 12  0.139682  0.947915  0.120648      0.953876  0.000031
# 13  0.137803  0.948377  0.120778      0.954494  0.000031
# 14  0.137971  0.948958  0.123066      0.953596  0.000031
# 15  0.136490  0.949226  0.117157      0.957584  0.000016
# 16  0.136445  0.949151  0.116968      0.956461  0.000016
# 17  0.134552  0.950000  0.115992      0.957584  0.000008
# 18  0.134514  0.949675  0.114106      0.957303  0.000004
# 19  0.134661  0.950094  0.116292      0.957135  0.000002

# %%
def metrics_plot(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1,len(acc)+1,1)

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
metrics_plot(history)

# %% [markdown]
# We can see the validation set had a performance which was underdamped and the settling time was equivalent to around 15 epochs, this is the main why we trained for 20 epochs and used ModelCheckpoint.
#
# In the next line we will load the model saved in the h5 file and confirm it's working properly if we want to use it in other moment avoiding training the model again.

# %%
from keras.models import load_model

model_saved = load_model('./CNN_model_histo.h5')
# Out:
# 2022-04-22 17:46:38.887611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:38.981926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:38.982056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:38.984029: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-22 17:46:38.985915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:38.986022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:38.986101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:40.271082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:40.271211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:40.271299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-22 17:46:40.272203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5020 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-04-22 17:46:40.273891: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# Here is where we have to use the copy of the validation set we created earlier which was unshuffled, we will evaluate the performance of this loaded model and predict the label for such images as follows:

# %%
#model_saved.save('CNN_model_histo.h5')

# %%
model_saved.evaluate(val2_gen, steps=len(df_val), verbose=1)
# Out:
# 17800/17800 [==============================] - 32s 2ms/step - loss: 0.1162 - accuracy: 0.9569
# [0.11618280410766602, 0.9569101333618164]

# %%
predicted_val_prob = model_saved.predict(val2_gen, steps=len(df_val), verbose=1)
# Out:
# 17800/17800 [==============================] - 32s 2ms/step

# %%
Y_val_pred= np.round(predicted_val_prob)
Y_val_pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %% [markdown]
# The next lines will compute error metrics such as accuracy, recall, precision, f1-score and area under the curve, shown as classification report and confusion matrix:

# %%
from sklearn.metrics import classification_report

y_true = val2_gen.classes
report = classification_report(y_true, Y_val_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      8900
#            1       0.95      0.96      0.96      8900
#
#     accuracy                           0.96     17800
#    macro avg       0.96      0.96      0.96     17800
# weighted avg       0.96      0.96      0.96     17800

# %%
from sklearn.metrics import confusion_matrix

f,ax = plt.subplots(figsize=(15, 15))
confusion_mtx = confusion_matrix(y_true, Y_val_pred)
sns.set(font_scale=1.4)
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray",ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix Validation set")
plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize

# %%
metrics = []

precision, recall, fscore, _ = score(y_true, Y_val_pred, average='weighted')
accuracy = accuracy_score(y_true, Y_val_pred)
auc = roc_auc_score(y_true, Y_val_pred)
metrics.append(pd.Series({'precision':precision, 'recall':recall,
                          'fscore':fscore, 'accuracy':accuracy,
                          'auc':auc}, name='CNN model'))
    
metrics = pd.concat(metrics, axis=1)

# %%
metrics
# Out:
#            CNN model
# precision   0.956208
# recall      0.956180
# fscore      0.956179
# accuracy    0.956180
# auc         0.956180

# %% [markdown]
# ## Inference:
#
# We will do almost the same process as before, we have to understand the unseen images and copy all of them in a new directory:

# %%
os.listdir('input/histopathologic-cancer-detection/test')[:5]
# Out:
# ['61f5792c2ae31fc1e0d5ee71b623aa6c435b5f31.tif',
#  'bb6f68db3c4bad997f75299277e63d8e5ee382c7.tif',
#  '4b61b957120f1fad85203e02ad73e5eef91cd414.tif',
#  '5c45d1613c88c0a58a47bb35ed9a441351dd9832.tif',
#  '1bc5b3da24dea364fbfd315c126a02091d2dac05.tif']

# %%
print('\n Amount of images in test dataset: ', len(os.listdir('input/histopathologic-cancer-detection/test')))
# Out:
#  Amount of images in test dataset:  57458

# %%
# create test_dir
test_dir = 'test_set_dir'
os.mkdir(test_dir)
    
# create test_images inside test_dir
test_images = os.path.join(test_dir, 'test_images')
os.mkdir(test_images)

# %%
# Transfer the test images into image_dir

test_list = os.listdir('input/histopathologic-cancer-detection/test')

for image in test_list:
    fname = image
    # source path to image
    src = os.path.join('input/histopathologic-cancer-detection/test', fname)
    # destination path to image
    dst = os.path.join(test_images, fname)
    # copy the image from the source to the destination
    shutil.copyfile(src, dst)

# %%
len(os.listdir('test_set_dir/test_images'))
# Out:
# 57458

# %% [markdown]
# Once we copied all images to our 'test_set_dir' directory we have to gather them using the flow_from_directory function as before and use it as argument of the prediction function:

# %%
test_path = 'test_set_dir'
test_gen = datagen.flow_from_directory(test_path,
                                       target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                       batch_size=1,
                                       class_mode='categorical',
                                       shuffle=False)
# Out:
# Found 57458 images belonging to 1 classes.

# %%
test_predictions = model_saved.predict(test_gen, steps=len(os.listdir('test_set_dir/test_images')), verbose=1)
# Out:
# 2022-04-22 17:47:06.340958: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8303
# 57458/57458 [==============================] - 138s 2ms/step

# %%
test_predictions
# Out:
# array([[2.3954285e-06],
#        [4.0369436e-02],
#        [9.4812147e-02],
#        ...,
#        [9.9998713e-01],
#        [4.4308186e-01],
#        [9.6124631e-01]], dtype=float32)

# %%
non_cancerous=1-test_predictions

# %% [markdown]
# The following line creates the csv file that we will submit:

# %%
submission=pd.DataFrame(non_cancerous, columns=['label'])
submission['id']=test_gen.filenames
submission['id']=submission['id'].str.split('/', n=1, expand=True)[1].str.split('.', n=1, expand=True)[0] 
submission.set_index('id', inplace=True)
submission.head()
# Out:
#                                              label
# id
# 00006537328c33e284c973d7b39d340809f7271b  0.999998
# 0000ec92553fda4ce39889f9226ace43cae3364e  0.959631
# 00024a6dee61f12f7856b0fc6be20bc7a48ba3d2  0.905188
# 000253dfaa0be9d0d100283b22284ab2f6b643f6  0.000321
# 000270442cc15af719583a8172c87cd2bd9c7746  0.017663

# %%
#submission.to_csv('submission.csv')

# %% [markdown]
# I would like to know any feedback in order to increase the performance of the models or tell me if you found a different one even better!
#
# If you liked this notebook I would appreciate so much your upvote if you want to see more projects/tutorials like this one. I encourage you to see my projects portfolio, am sure you will love it.
#
# Thank you!

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array
my_img=load_img('test/a.tif',target_size=(IMAGE_SIZE,IMAGE_SIZE))
my_img=img_to_array(my_img)
my_img=my_img.reshape((1,my_img.shape[0],my_img.shape[1],my_img.shape[2]))
pred=model_saved.predict(my_img,verbose=1)
pred
# Out:
# 1/1 [==============================] - 0s 81ms/step
# array([[1.]], dtype=float32)

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
mob_netv2=MobileNetV2(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3),include_top=False,weights='imagenet')
for layer in mob_netv2.layers:
    layer.trainable=False
mob_net_model=Sequential()
mob_net_model.add(mob_netv2)
mob_net_model.add(Flatten())
mob_net_model.add(Dense(512,activation='relu'))
mob_net_model.add(BatchNormalization())
mob_net_model.add(Dropout(0.2))
mob_net_model.add(Dense(1,activation='sigmoid'))

mob_net_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
mob_net_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_96 (Functi  (None, 3, 3, 1280)       2257984
#  onal)
#
#  flatten_2 (Flatten)         (None, 11520)             0
#
#  dense_4 (Dense)             (None, 512)               5898752
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 8,159,297
# Trainable params: 5,900,289
# Non-trainable params: 2,259,008
# _________________________________________________________________

# %%
mob_model_dir = 'Mobile_netv2.h5'
datagen_mob = ImageDataGenerator(
                             featurewise_center=False,
                             samplewise_center=False,
                             featurewise_std_normalization=False,
                             samplewise_std_normalization=False,
                             zca_whitening=False,
                             rotation_range=10,
                             zoom_range = 0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True,
                             preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input)
train_gen_mob = datagen_mob.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='binary',
                                        shuffle=True)

val_gen_mob = datagen_mob.flow_from_directory(valid_path,
                                      target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                      batch_size=val_batch_size,
                                      class_mode='binary',
                                      shuffle=True)

mob_checkpoint = ModelCheckpoint(mob_model_dir, monitor='val_accuracy', verbose=1,
                             save_best_only=True, mode='max')
history_mob_net = mob_net_model.fit(train_gen_mob, validation_data=val_gen_mob,
                              epochs=20, verbose=1,
                              callbacks=[lr_reduction, mob_checkpoint])
# Out:
# Found 160200 images belonging to 2 classes.
# Found 17800 images belonging to 2 classes.
# Epoch 1/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3585 - accuracy: 0.8428
# Epoch 1: val_accuracy improved from -inf to 0.85629, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 317s 63ms/step - loss: 0.3585 - accuracy: 0.8428 - val_loss: 0.3159 - val_accuracy: 0.8563 - lr: 0.0010
# Epoch 2/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8573
# Epoch 2: val_accuracy improved from 0.85629 to 0.87067, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 282s 56ms/step - loss: 0.3297 - accuracy: 0.8572 - val_loss: 0.3098 - val_accuracy: 0.8707 - lr: 0.0010
# Epoch 3/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3190 - accuracy: 0.8619
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 3: val_accuracy did not improve from 0.87067
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3190 - accuracy: 0.8619 - val_loss: 0.3177 - val_accuracy: 0.8625 - lr: 0.0010
# Epoch 4/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8681
# Epoch 4: val_accuracy improved from 0.87067 to 0.87635, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3069 - accuracy: 0.8681 - val_loss: 0.2845 - val_accuracy: 0.8763 - lr: 5.0000e-04
# Epoch 5/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3021 - accuracy: 0.8697
# Epoch 5: val_accuracy improved from 0.87635 to 0.88034, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.3021 - accuracy: 0.8697 - val_loss: 0.2777 - val_accuracy: 0.8803 - lr: 5.0000e-04
# Epoch 6/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3001 - accuracy: 0.8721
# Epoch 6: val_accuracy improved from 0.88034 to 0.88129, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3001 - accuracy: 0.8721 - val_loss: 0.2771 - val_accuracy: 0.8813 - lr: 5.0000e-04
# Epoch 7/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8760
# Epoch 7: val_accuracy improved from 0.88129 to 0.88551, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.2937 - accuracy: 0.8760 - val_loss: 0.2757 - val_accuracy: 0.8855 - lr: 5.0000e-04
# Epoch 8/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.8758
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 8: val_accuracy did not improve from 0.88551
# 5007/5007 [==============================] - 248s 49ms/step - loss: 0.2931 - accuracy: 0.8758 - val_loss: 0.2683 - val_accuracy: 0.8847 - lr: 5.0000e-04
# Epoch 9/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.8768
# Epoch 9: val_accuracy improved from 0.88551 to 0.88798, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 247s 49ms/step - loss: 0.2891 - accuracy: 0.8768 - val_loss: 0.2671 - val_accuracy: 0.8880 - lr: 2.5000e-04
# Epoch 10/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2867 - accuracy: 0.8791
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 10: val_accuracy did not improve from 0.88798
# 5007/5007 [==============================] - 248s 49ms/step - loss: 0.2867 - accuracy: 0.8791 - val_loss: 0.2662 - val_accuracy: 0.8866 - lr: 2.5000e-04
# Epoch 11/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.8807
# Epoch 11: val_accuracy improved from 0.88798 to 0.88955, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.2820 - accuracy: 0.8807 - val_loss: 0.2611 - val_accuracy: 0.8896 - lr: 1.2500e-04
# Epoch 12/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8808
# Epoch 12: val_accuracy improved from 0.88955 to 0.89287, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2824 - accuracy: 0.8808 - val_loss: 0.2592 - val_accuracy: 0.8929 - lr: 1.2500e-04
# Epoch 13/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2801 - accuracy: 0.8819
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 13: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2801 - accuracy: 0.8819 - val_loss: 0.2603 - val_accuracy: 0.8894 - lr: 1.2500e-04
# Epoch 14/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8834
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 14: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 248s 50ms/step - loss: 0.2777 - accuracy: 0.8834 - val_loss: 0.2555 - val_accuracy: 0.8921 - lr: 6.2500e-05
# Epoch 15/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8829
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 15: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2767 - accuracy: 0.8829 - val_loss: 0.2556 - val_accuracy: 0.8926 - lr: 3.1250e-05
# Epoch 16/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.8840
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 16: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2771 - accuracy: 0.8840 - val_loss: 0.2576 - val_accuracy: 0.8896 - lr: 1.5625e-05
# Epoch 17/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2767 - accuracy: 0.8830
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 17: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.2767 - accuracy: 0.8830 - val_loss: 0.2586 - val_accuracy: 0.8918 - lr: 7.8125e-06
# Epoch 18/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.8839
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 18: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.2764 - accuracy: 0.8839 - val_loss: 0.2567 - val_accuracy: 0.8920 - lr: 3.9063e-06
# Epoch 19/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8852
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 19: val_accuracy did not improve from 0.89287
# 5007/5007 [==============================] - 248s 49ms/step - loss: 0.2739 - accuracy: 0.8852 - val_loss: 0.2574 - val_accuracy: 0.8910 - lr: 1.9531e-06
# Epoch 20/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.2769 - accuracy: 0.8830
# Epoch 20: val_accuracy improved from 0.89287 to 0.89348, saving model to Mobile_netv2.h5
# 5007/5007 [==============================] - 247s 49ms/step - loss: 0.2768 - accuracy: 0.8830 - val_loss: 0.2565 - val_accuracy: 0.8935 - lr: 1.0000e-06

# %%
from tensorflow.keras.applications import ResNet50V2

# %%
res_netv2=ResNet50V2(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3),include_top=False,weights='imagenet')
for layer in res_netv2.layers:
    layer.trainable=False
res_net_model=Sequential()
res_net_model.add(res_netv2)
res_net_model.add(Flatten())
res_net_model.add(Dense(512,activation='relu'))
res_net_model.add(BatchNormalization())
res_net_model.add(Dropout(0.2))
res_net_model.add(Dense(1,activation='sigmoid'))

res_net_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
res_net_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 3, 3, 2048)        23564800
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_6 (Dense)             (None, 512)               9437696
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 33,005,057
# Trainable params: 9,439,233
# Non-trainable params: 23,565,824
# _________________________________________________________________

# %%
res_model_dir = 'ResNetv2.h5'
datagen_res = ImageDataGenerator(
                             featurewise_center=False,
                             samplewise_center=False,
                             featurewise_std_normalization=False,
                             samplewise_std_normalization=False,
                             zca_whitening=False,
                             rotation_range=10,
                             zoom_range = 0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True,
                             preprocessing_function=tf.keras.applications.resnet_v2.preprocess_input)
train_gen_res = datagen_res.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='binary',
                                        shuffle=True)

val_gen_res = datagen_res.flow_from_directory(valid_path,
                                      target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                      batch_size=val_batch_size,
                                      class_mode='binary',
                                      shuffle=True)
res_checkpoint = ModelCheckpoint(res_model_dir, monitor='val_accuracy', verbose=1,
                             save_best_only=True, mode='max')
history_res_net = res_net_model.fit(train_gen_res, validation_data=val_gen_res,
                              epochs=20, verbose=1,
                              callbacks=[lr_reduction, res_checkpoint])
# Out:
# Found 160200 images belonging to 2 classes.
# Found 17800 images belonging to 2 classes.
# Epoch 1/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4085 - accuracy: 0.8170
# Epoch 1: val_accuracy improved from -inf to 0.83730, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 255s 50ms/step - loss: 0.4084 - accuracy: 0.8170 - val_loss: 0.3632 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 2/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3767 - accuracy: 0.8317
# Epoch 2: val_accuracy improved from 0.83730 to 0.84730, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3767 - accuracy: 0.8317 - val_loss: 0.3484 - val_accuracy: 0.8473 - lr: 0.0010
# Epoch 3/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3664 - accuracy: 0.8378
# Epoch 3: val_accuracy improved from 0.84730 to 0.85438, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 253s 50ms/step - loss: 0.3664 - accuracy: 0.8378 - val_loss: 0.3346 - val_accuracy: 0.8544 - lr: 0.0010
# Epoch 4/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8417
# Epoch 4: val_accuracy improved from 0.85438 to 0.85517, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3576 - accuracy: 0.8417 - val_loss: 0.3290 - val_accuracy: 0.8552 - lr: 0.0010
# Epoch 5/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3525 - accuracy: 0.8445
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.85517
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3525 - accuracy: 0.8444 - val_loss: 0.3297 - val_accuracy: 0.8530 - lr: 0.0010
# Epoch 6/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.8478
# Epoch 6: val_accuracy improved from 0.85517 to 0.86112, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3442 - accuracy: 0.8478 - val_loss: 0.3216 - val_accuracy: 0.8611 - lr: 5.0000e-04
# Epoch 7/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3410 - accuracy: 0.8504
# Epoch 7: val_accuracy improved from 0.86112 to 0.86416, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3410 - accuracy: 0.8504 - val_loss: 0.3188 - val_accuracy: 0.8642 - lr: 5.0000e-04
# Epoch 8/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8522
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 8: val_accuracy did not improve from 0.86416
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3367 - accuracy: 0.8522 - val_loss: 0.3172 - val_accuracy: 0.8618 - lr: 5.0000e-04
# Epoch 9/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3331 - accuracy: 0.8552
# Epoch 9: val_accuracy improved from 0.86416 to 0.86438, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3331 - accuracy: 0.8552 - val_loss: 0.3134 - val_accuracy: 0.8644 - lr: 2.5000e-04
# Epoch 10/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8559
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 10: val_accuracy did not improve from 0.86438
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.3305 - accuracy: 0.8559 - val_loss: 0.3140 - val_accuracy: 0.8629 - lr: 2.5000e-04
# Epoch 11/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8561
# Epoch 11: val_accuracy improved from 0.86438 to 0.86747, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3296 - accuracy: 0.8561 - val_loss: 0.3069 - val_accuracy: 0.8675 - lr: 1.2500e-04
# Epoch 12/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3280 - accuracy: 0.8568
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 12: val_accuracy did not improve from 0.86747
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3279 - accuracy: 0.8568 - val_loss: 0.3081 - val_accuracy: 0.8669 - lr: 1.2500e-04
# Epoch 13/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3259 - accuracy: 0.8591
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 13: val_accuracy improved from 0.86747 to 0.86753, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3259 - accuracy: 0.8591 - val_loss: 0.3055 - val_accuracy: 0.8675 - lr: 6.2500e-05
# Epoch 14/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.8592
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 14: val_accuracy did not improve from 0.86753
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3255 - accuracy: 0.8592 - val_loss: 0.3073 - val_accuracy: 0.8658 - lr: 3.1250e-05
# Epoch 15/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.8579
# Epoch 15: val_accuracy improved from 0.86753 to 0.87000, saving model to ResNetv2.h5
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.3240 - accuracy: 0.8579 - val_loss: 0.3046 - val_accuracy: 0.8700 - lr: 1.5625e-05
# Epoch 16/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.8589
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 16: val_accuracy did not improve from 0.87000
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3245 - accuracy: 0.8589 - val_loss: 0.3075 - val_accuracy: 0.8652 - lr: 1.5625e-05
# Epoch 17/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8574
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 17: val_accuracy did not improve from 0.87000
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3266 - accuracy: 0.8574 - val_loss: 0.3053 - val_accuracy: 0.8668 - lr: 7.8125e-06
# Epoch 18/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3249 - accuracy: 0.8580
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 18: val_accuracy did not improve from 0.87000
# 5007/5007 [==============================] - 248s 50ms/step - loss: 0.3248 - accuracy: 0.8580 - val_loss: 0.3064 - val_accuracy: 0.8658 - lr: 3.9063e-06
# Epoch 19/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3232 - accuracy: 0.8608
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 19: val_accuracy did not improve from 0.87000
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.3232 - accuracy: 0.8608 - val_loss: 0.3034 - val_accuracy: 0.8689 - lr: 1.9531e-06
# Epoch 20/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.8591
# Epoch 20: val_accuracy did not improve from 0.87000
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3244 - accuracy: 0.8591 - val_loss: 0.3054 - val_accuracy: 0.8671 - lr: 1.0000e-06

# %%
metrics_plot(history_mob_net)

# %%
metrics_plot(history_res_net)

# %%
mob_net_df=pd.DataFrame(history_mob_net.history)
mob_net_df.to_csv("MobileNetV2stats.csv")
mob_net_df
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   0.358510  0.842815  0.315911      0.856292  0.001000
# 1   0.329697  0.857241  0.309792      0.870674  0.001000
# 2   0.319023  0.861916  0.317726      0.862528  0.001000
# 3   0.306943  0.868090  0.284500      0.876348  0.000500
# 4   0.302098  0.869669  0.277729      0.880337  0.000500
# 5   0.300130  0.872122  0.277140      0.881292  0.000500
# 6   0.293724  0.875974  0.275735      0.885506  0.000500
# 7   0.293097  0.875755  0.268298      0.884663  0.000500
# 8   0.289120  0.876798  0.267137      0.887978  0.000250
# 9   0.286694  0.879070  0.266199      0.886573  0.000250
# 10  0.281996  0.880662  0.261079      0.889551  0.000125
# 11  0.282372  0.880793  0.259241      0.892865  0.000125
# 12  0.280125  0.881929  0.260289      0.889382  0.000125
# 13  0.277695  0.883358  0.255547      0.892135  0.000063
# 14  0.276740  0.882940  0.255633      0.892584  0.000031
# 15  0.277054  0.883976  0.257601      0.889551  0.000016
# 16  0.276709  0.882978  0.258565      0.891798  0.000008
# 17  0.276429  0.883876  0.256702      0.891966  0.000004
# 18  0.273892  0.885250  0.257354      0.890955  0.000002
# 19  0.276826  0.883021  0.256460      0.893483  0.000001

# %%
res_net_df=pd.DataFrame(history_res_net.history)
res_net_df.to_csv("ResNet50V2stats.csv")
res_net_df
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   0.408431  0.816979  0.363190      0.837303  0.001000
# 1   0.376717  0.831679  0.348392      0.847303  0.001000
# 2   0.366426  0.837803  0.334551      0.854382  0.001000
# 3   0.357605  0.841679  0.328956      0.855169  0.001000
# 4   0.352531  0.844444  0.329706      0.852978  0.001000
# 5   0.344234  0.847834  0.321601      0.861124  0.000500
# 6   0.340992  0.850368  0.318834      0.864157  0.000500
# 7   0.336667  0.852197  0.317203      0.861798  0.000500
# 8   0.333137  0.855181  0.313386      0.864382  0.000250
# 9   0.330471  0.855936  0.313965      0.862865  0.000250
# 10  0.329621  0.856105  0.306914      0.867472  0.000125
# 11  0.327938  0.856779  0.308062      0.866854  0.000125
# 12  0.325851  0.859120  0.305512      0.867528  0.000063
# 13  0.325544  0.859238  0.307332      0.865843  0.000031
# 14  0.324041  0.857903  0.304619      0.870000  0.000016
# 15  0.324533  0.858901  0.307463      0.865225  0.000016
# 16  0.326582  0.857353  0.305316      0.866798  0.000008
# 17  0.324829  0.858046  0.306429      0.865843  0.000004
# 18  0.323172  0.860774  0.303366      0.868933  0.000002
# 19  0.324378  0.859145  0.305372      0.867079  0.000001

# %%
from tensorflow.keras.applications import InceptionV3

# %%
incepnet=InceptionV3(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3),include_top=False,weights='imagenet')
for layer in incepnet.layers:
    layer.trainable=False
incepnet_model=Sequential()
incepnet_model.add(incepnet)
incepnet_model.add(Flatten())
incepnet_model.add(Dense(512,activation='relu'))
incepnet_model.add(BatchNormalization())
incepnet_model.add(Dropout(0.2))
incepnet_model.add(Dense(1,activation='sigmoid'))

incepnet_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
incepnet_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 1, 1, 2048)        21802784
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dense_10 (Dense)            (None, 512)               1049088
#
#  batch_normalization_193 (Ba  (None, 512)              2048
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 22,854,433
# Trainable params: 1,050,625
# Non-trainable params: 21,803,808
# _________________________________________________________________

# %%
incep_model_dir = 'InceptionNetV3.h5'
datagen_incep = ImageDataGenerator(
                             featurewise_center=False,
                             samplewise_center=False,
                             featurewise_std_normalization=False,
                             samplewise_std_normalization=False,
                             zca_whitening=False,
                             rotation_range=10,
                             zoom_range = 0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True,
                             preprocessing_function=tf.keras.applications.inception_v3.preprocess_input)
train_gen_incep = datagen_incep.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='binary',
                                        shuffle=True)

val_gen_incep = datagen_incep.flow_from_directory(valid_path,
                                      target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                      batch_size=val_batch_size,
                                      class_mode='binary',
                                      shuffle=True)
incep_checkpoint = ModelCheckpoint(incep_model_dir, monitor='val_accuracy', verbose=1,
                             save_best_only=True, mode='max')
history_incep_net = incepnet_model.fit(train_gen_incep, validation_data=val_gen_incep,
                              epochs=20, verbose=1,
                              callbacks=[lr_reduction, incep_checkpoint])
# Out:
# Found 160200 images belonging to 2 classes.
# Found 17800 images belonging to 2 classes.
# Epoch 1/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4571 - accuracy: 0.7878
# Epoch 1: val_accuracy improved from -inf to 0.80899, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 256s 51ms/step - loss: 0.4571 - accuracy: 0.7878 - val_loss: 0.4174 - val_accuracy: 0.8090 - lr: 0.0010
# Epoch 2/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.7996
# Epoch 2: val_accuracy improved from 0.80899 to 0.80989, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.4338 - accuracy: 0.7996 - val_loss: 0.4153 - val_accuracy: 0.8099 - lr: 0.0010
# Epoch 3/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8031
# Epoch 3: val_accuracy improved from 0.80989 to 0.81506, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.4283 - accuracy: 0.8031 - val_loss: 0.4053 - val_accuracy: 0.8151 - lr: 0.0010
# Epoch 4/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4247 - accuracy: 0.8042
# Epoch 4: val_accuracy improved from 0.81506 to 0.82073, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.4246 - accuracy: 0.8042 - val_loss: 0.3974 - val_accuracy: 0.8207 - lr: 0.0010
# Epoch 5/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4194 - accuracy: 0.8083
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy improved from 0.82073 to 0.82079, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.4193 - accuracy: 0.8083 - val_loss: 0.3963 - val_accuracy: 0.8208 - lr: 0.0010
# Epoch 6/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4133 - accuracy: 0.8121
# Epoch 6: val_accuracy improved from 0.82079 to 0.82449, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.4133 - accuracy: 0.8121 - val_loss: 0.3899 - val_accuracy: 0.8245 - lr: 5.0000e-04
# Epoch 7/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8138
# Epoch 7: val_accuracy improved from 0.82449 to 0.82517, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.4102 - accuracy: 0.8138 - val_loss: 0.3847 - val_accuracy: 0.8252 - lr: 5.0000e-04
# Epoch 8/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4076 - accuracy: 0.8143
# Epoch 8: val_accuracy improved from 0.82517 to 0.82708, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.4076 - accuracy: 0.8143 - val_loss: 0.3854 - val_accuracy: 0.8271 - lr: 5.0000e-04
# Epoch 9/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4081 - accuracy: 0.8140
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 9: val_accuracy did not improve from 0.82708
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.4081 - accuracy: 0.8140 - val_loss: 0.3891 - val_accuracy: 0.8228 - lr: 5.0000e-04
# Epoch 10/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8170
# Epoch 10: val_accuracy improved from 0.82708 to 0.82955, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.4046 - accuracy: 0.8170 - val_loss: 0.3846 - val_accuracy: 0.8296 - lr: 2.5000e-04
# Epoch 11/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8172
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 11: val_accuracy did not improve from 0.82955
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.4034 - accuracy: 0.8172 - val_loss: 0.3804 - val_accuracy: 0.8287 - lr: 2.5000e-04
# Epoch 12/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.4012 - accuracy: 0.8184
# Epoch 12: val_accuracy improved from 0.82955 to 0.83124, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 251s 50ms/step - loss: 0.4012 - accuracy: 0.8184 - val_loss: 0.3797 - val_accuracy: 0.8312 - lr: 1.2500e-04
# Epoch 13/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8185
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 13: val_accuracy did not improve from 0.83124
# 5007/5007 [==============================] - 249s 50ms/step - loss: 0.4003 - accuracy: 0.8185 - val_loss: 0.3764 - val_accuracy: 0.8311 - lr: 1.2500e-04
# Epoch 14/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3992 - accuracy: 0.8203
# Epoch 14: val_accuracy improved from 0.83124 to 0.83427, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.3992 - accuracy: 0.8203 - val_loss: 0.3781 - val_accuracy: 0.8343 - lr: 6.2500e-05
# Epoch 15/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.3982 - accuracy: 0.8195
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 15: val_accuracy did not improve from 0.83427
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3982 - accuracy: 0.8195 - val_loss: 0.3778 - val_accuracy: 0.8275 - lr: 6.2500e-05
# Epoch 16/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3992 - accuracy: 0.8192
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 16: val_accuracy improved from 0.83427 to 0.83433, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 255s 51ms/step - loss: 0.3992 - accuracy: 0.8192 - val_loss: 0.3708 - val_accuracy: 0.8343 - lr: 3.1250e-05
# Epoch 17/20
# 5007/5007 [==============================] - ETA: 0s - loss: 0.4000 - accuracy: 0.8196
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 17: val_accuracy did not improve from 0.83433
# 5007/5007 [==============================] - 250s 50ms/step - loss: 0.4000 - accuracy: 0.8196 - val_loss: 0.3809 - val_accuracy: 0.8296 - lr: 1.5625e-05
# Epoch 18/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8188
# Epoch 18: val_accuracy improved from 0.83433 to 0.83562, saving model to InceptionNetV3.h5
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3998 - accuracy: 0.8188 - val_loss: 0.3749 - val_accuracy: 0.8356 - lr: 7.8125e-06
# Epoch 19/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3986 - accuracy: 0.8192
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 19: val_accuracy did not improve from 0.83562
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3986 - accuracy: 0.8192 - val_loss: 0.3789 - val_accuracy: 0.8285 - lr: 7.8125e-06
# Epoch 20/20
# 5006/5007 [============================>.] - ETA: 0s - loss: 0.3976 - accuracy: 0.8197
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 20: val_accuracy did not improve from 0.83562
# 5007/5007 [==============================] - 252s 50ms/step - loss: 0.3976 - accuracy: 0.8197 - val_loss: 0.3814 - val_accuracy: 0.8303 - lr: 3.9063e-06

# %%
metrics_plot(history_incep_net)

# %%
incep_net_df=pd.DataFrame(history_incep_net.history)
incep_net_df.to_csv("InceptionV3stats.csv")
incep_net_df
# Out:
#         loss  accuracy  val_loss  val_accuracy        lr
# 0   0.457112  0.787815  0.417369      0.808989  0.001000
# 1   0.433820  0.799551  0.415321      0.809888  0.001000
# 2   0.428348  0.803090  0.405273      0.815056  0.001000
# 3   0.424639  0.804245  0.397361      0.820730  0.001000
# 4   0.419321  0.808321  0.396307      0.820787  0.001000
# 5   0.413282  0.812110  0.389911      0.824494  0.000500
# 6   0.410189  0.813752  0.384724      0.825169  0.000500
# 7   0.407607  0.814313  0.385373      0.827079  0.000500
# 8   0.408096  0.814007  0.389100      0.822809  0.000500
# 9   0.404591  0.816966  0.384581      0.829551  0.000250
# 10  0.403363  0.817241  0.380416      0.828652  0.000250
# 11  0.401235  0.818415  0.379653      0.831236  0.000125
# 12  0.400307  0.818489  0.376399      0.831067  0.000125
# 13  0.399176  0.820262  0.378099      0.834270  0.000063
# 14  0.398168  0.819457  0.377838      0.827528  0.000063
# 15  0.399201  0.819245  0.370814      0.834326  0.000031
# 16  0.400020  0.819638  0.380897      0.829607  0.000016
# 17  0.399848  0.818826  0.374854      0.835618  0.000008
# 18  0.398637  0.819214  0.378885      0.828483  0.000008
# 19  0.397616  0.819707  0.381434      0.830281  0.000004
